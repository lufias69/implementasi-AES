# %%
#data\kunci jawaban dosen
import pandas as pd
import numpy as np

# %%
from os import listdir
from os.path import isfile, join
def dfile (path):
    mypath = path
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    return onlyfiles

# %%
jawaban_file = dfile ("data/jawaban")
jawaban_file
# Out:
# ['S1a.xlsx',
#  'S1b.xlsx',
#  'S2a.xlsx',
#  'S2b.xlsx',
#  'S3.xlsx',
#  'S4.xlsx',
#  'S5.xlsx']

# %%
df = pd.read_excel("data\kunci jawaban dosen\kunci_jawaban_dosen.xlsx")
kode = df.kode.tolist()
skor = df.skor.tolist()
kunci_jawaban = df.jawaban_jawaban.tolist()

# %%
from aes_class import AES

# %% [markdown]
# # Menggunakan QE

# %%
# model_dict = dict()
dict_hasil = dict()

# print(model.train([kj], [sk]))
for jwb_f, kd, sk, kj in zip(jawaban_file, kode, skor, kunci_jawaban):
    model=  AES.AES(tf=True, qe=True, ngram=True, n=1, stemming=True)#otak atik disini
    model.train([kj], [sk])
    df = pd.read_excel("data/jawaban/"+jwb_f)
    jawaban_list = df.jawaban.tolist()
    sim_list = list()
    print("#", end=" ")
#     print(jawaban_list)
    for j in jawaban_list:
        model.predict(j)
        similarity = model.hasil_cosine_similarity
        sim_list.append(similarity[0])
        print(".", end="")
    dict_hasil.update({kd:sim_list})
#     model_dict.update({kd:md})
# Out:
# tf ngram
# # ..........................................tf ngram
# # ..........................................tf ngram
# # ..........................................tf ngram
# # ..........................................tf ngram
# # ......

# %%
hasil_df = pd.DataFrame.from_dict(dict_hasil)
hasil_df

# %% [markdown]
# # Tanpa QE

# %%
# model_dict = dict()
dict_hasilTanpa = dict()

# print(model.train([kj], [sk]))
for jwb_f, kd, sk, kj in zip(jawaban_file, kode, skor, kunci_jawaban):
    model=  AES.AES(tf=True, qe=False, ngram=True, n=1, stemming=True) #otak atik disini
    model.train([kj], [sk])
    df = pd.read_excel("data/jawaban/"+jwb_f)
    jawaban_list = df.jawaban.tolist()
    sim_list = list()
    print("#", end=" ")
#     print(jawaban_list)
    for j in jawaban_list:
#         try:
        model.predict(j)
#         except:
#             print(j)
#             break
        similarity = model.hasil_cosine_similarity
        sim_list.append(similarity[0])
        print(".", end="")
    dict_hasilTanpa.update({kd:sim_list})
#     model_dict.update({kd:md})
# Out:
# tf ngram
# # ..........................................tf ngram
# # ..........................................tf ngram
# # ..........................................tf ngram
# # ..........................................tf ngram
# # ..........................................tf ngram
# # ..........................................tf ngram
# # ..........................................

# %%
hasil_df = pd.DataFrame.from_dict(dict_hasilTanpa)
hasil_df
# Out:
#          s1a       s1b       s2a       s2b        s3        s4        s5
# 0   0.417533  0.414370  0.549762  0.538993  0.900975  0.589256  0.604743
# 1   0.515779  0.551943  0.658323  0.323029  0.485546  0.589256  0.377964
# 2   0.451414  0.319546  0.172774  0.240772  0.776518  0.596285  0.267261
# 3   0.455661  0.490970  0.677674  0.635223  0.825717  0.589256  0.657376
